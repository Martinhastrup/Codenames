# %% [markdown]
# # Codenames AI

# %%
from utils.Codenames import GameMaster

# %%
gm = GameMaster()

# %%
display(gm.plot_board())
# Out:
# Dropdown(description='Select Target', options=('bald', 'basketball', 'box', 'calculator', 'chair', 'dart', 'da…
# Button(description='Eliminate', style=ButtonStyle())
# Output()
# Button(description='End Turn', style=ButtonStyle())
# Output()
# None

# %%
gm.produce_hint()
# Out:
# Button(description='Hint', style=ButtonStyle())
# Output()
# BRAZIL, 2
# VIOLIN, 1
# MECHANIC, 2
# THEATRE, 1
# DRIVER, 2
# GOAT, 2
# KOREA, 1
# MOUSE, 2
# TESTICLES, 1
# SCREW, 2
# WINE, 2
# CREEK, 1

# %%
gm.reset_board_state()
